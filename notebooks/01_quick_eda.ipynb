# %% [markdown]
# # Quick EDA (Synthetic)\nRun `python src/run_all.py` first.

# %%
import pandas as pd\nmw = pd.read_csv('../data/processed/member_week_pilot.csv')\nms = pd.read_csv('../data/processed/member_summary.csv')\nmw.head()\n
